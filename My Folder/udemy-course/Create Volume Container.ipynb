-- %% [markdown]
-- # Legacy DBFS no longer works
-- Because I have just spun up a new Azure account, Databricks completely removed the ability to use or re-enable the legacy DBFS root at the platform architecture level. The toggle button simply doesn't exist for envs created recently, meaning we must pivot to the current, modern approach: **Unity Catalog Volumes**.

-- %%
CREATE VOLUME udemycourseworkspace.default.bookstore_data;
